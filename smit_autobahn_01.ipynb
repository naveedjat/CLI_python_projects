# %% [markdown]
# <a href="https://colab.research.google.com/github/naveedjat/CLI_python_projects/blob/main/smit_autobahn_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First of all , I have created an variable which has a string value.
x = 'naveed'
y = 'My Name is Naveed'

# %%
#  Case Conversion : Used when inconsistent capitalization.

# x.capitalize()   # Naveed              # capitalizes the word
# x.upper()        # NAVEED              # make the word uppercase
# x.lower()        # naveed              # make the word lowercase

# y.title()        # My Name Is Naveed   # it converts the text to title
# y.swapcase()     # mY nAME IS nAVEED   # it reverse the case of text .
# y.casefold()     # my name is naveed   # it is strongest lowercase (NLP).
# Out:
# 'My Name is Naveed'

# %%
# Searching and finding : Useful when filtering dataset columns.
# y.find('Naveed')     # 11
# y.index('Naveed')    # 11
# y.rfind('Naveed')    # 11
# y.count('N')         # 2

# x.startswith('n')    # True
# x.endswith('d')      # True
# Out:
# True

# %%
# Checking and Validation : Used to verify data quality
# x.isalpha()          #True         # only alphabets
# x.isalnum()          #True         # checks if number contained or not
# x.isdecimal()        #False        # checks if decimal contained or not
# x.isdigit()          #False        # only digits
# x.islower()          #True         # all lowercase
# x.isnumeric()        #False        # numeric values
# x.isupper()          #False        # all uppercase
# x.istitle()          #False        # checks if it is title
# x.isascii()          #True         # detect weird unicode
# x.isprintable()      #True         # Checks if printable
# x.isspace()          #False        # only spaces
# x.isidentifier()     #True
# Out:
# True

# %%
# Splitting & Joining

# y.split()            # ['My', 'Name', 'is', 'Naveed']
# y.split('is')        # ['My Name ', ' Naveed']
# y.rsplit()           # ['My', 'Name', 'is', 'Naveed']
# y.splitlines()       # ['My Name is Naveed']
# y.join('[]')         # [My Name is Naveed]
# y.partition('is')    #('My Name ', 'is', ' Naveed')
# Out:
# 'My Name is Naveed'

# %%
# Remove Spaces /Replacing/ Cleaning Noise

#x.strip()              # 'naveed'
# x.lstrip()            # 'naveed'
# x.rstrip()            # 'naveed'
# x.replace('n','N')    # Naveed
# Out:
# 'naveed'

# %%
# Alignment / Formatting

# x.center(10)     # '  naveed  '
# x.ljust(10)      # 'naveed    '
# x.rjust(10)      # '    naveed'
# x.zfill(10)      # '0000naveed'
# x.encode()       # b'naveed'
# Out:
# b'naveed'
